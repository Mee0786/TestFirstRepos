# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Meena Jadhav**

# %% [markdown]
# _I am interested in data science as love working with data and would like to explore new methodologies and technologies to play with it to gain more meaningful insights from it._

# %% [markdown]
# ## The following code displays Lorenz equation

# %%
from IPython.display import display, Math

sigma = 10
rho = 28
beta = 8/3

display(Math(r'\frac{dx}{dt} = \Sigma \cdot (y - x)'))
display(Math(r'\frac{dy}{dt} = x \cdot (\rho - z) - y'))
display(Math(r'\frac{dz}{dt} = x \cdot y - \beta \cdot z'))
# Out:
# $\displaystyle \frac{dx}{dt} = \Sigma \cdot (y - x)$
# $\displaystyle \frac{dy}{dt} = x \cdot (\rho - z) - y$
# $\displaystyle \frac{dz}{dt} = x \cdot y - \beta \cdot z$

# %% [markdown]
# ### Horzontal rule

# %% [markdown]
# ---

# %% [markdown]
# ____

# %% [markdown]
# ### Link
#
# [www.ibm.com](https://www.ibm.com "IBM's Homepage")

# %% [markdown]
# ### Unordered list
#
# * Apple
# * Melon
# * Sweet lime
# * Grapes

# %% [markdown]
# ### Below is code highlight
#
# `This is how we can right code` its fun
